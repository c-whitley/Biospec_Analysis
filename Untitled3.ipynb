# %%
import spectral.io.envi as env
import spectral

import matplotlib.pyplot as plt
import numpy as np

# %%
file = r"E:\Breast_Cancer_US_dataset\br1003-br2085b\br1003-br2085b"
header = r"E:\Breast_Cancer_US_dataset\br1003-br2085b\br1003-br2085b.hdr"

img = envi.open(header, file)

# %%
plt.imshow(img.read_band(50))

# %%
spectral.imshow(img, (29, 19, 9))
# Out:
# ImageView object:
#   Display bands       :  (29, 19, 9)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [-0.18523478507995605, 0.7837232351303101]
#     G: [-0.2982504367828369, 0.7897186279296875]
#     B: [-0.5072095394134521, 0.8729493618011475]

# %%
import pandas as pd

# %%
dfs[5][0].value_counts()
# Out:
# Non_malignant Stroma    20179
# Name: 0, dtype: int64

# %%
dfs = {i: pd.read_csv(r"F:\fold_{}.csv".format(i), header = None) for i in range(1,6)}

# %%
for name, df in dfs.items():
    
    #plt.plot(df.mean(axis = 0, numeric_only  = True), label = name)
    
plt.legend()
