# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
brc961 = pd.read_pickle("/home/conor/Desktop/BRC961/BRC961.pickle")

# %%
brc961 = pd.read_pickle("/home/conor/Desktop/2085-b/BR2085b_u.pickle")

# %%
plt.plot(df.sample(10).mean(axis = 0))

# %%
df.size
# Out:
# 57578286

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
import Tissue_Analysis_Tools as TAT

# %%
RB = brc961.sample(5000).apply(lambda row: TAT.Rubber_Band_Correction().fit_transform(brc961.columns, row.values), axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-c3a5cd934d0e> in <module>
# ----> 1 RB = brc961.sample(5000).apply(lambda row: TAT.Rubber_Band_Correction().fit_transform(brc961.columns, row), axis = 0)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     255
# ...

# %%
for name, df in brc961.groupby("Grade"):
    
    plt.plot(df.mean(axis = 0, numeric_only = True), label = name)
    
plt.legend()

# %%
brc961.reset_index()["Grade"].value_counts()
# Out:
# 2         160690
# -          97117
# 3          35411
# 1 -- 2     14358
# 2 -- 3     10944
# 1           6198
# Name: Grade, dtype: int64
