# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from scipy.io import loadmat
# Out:
# C:\Users\Conor\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# C:\Users\Conor\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %% [markdown]
# Digitising secondary protein spectra

# %%
secondary_protein_file = r"C:\Users\Conor\Google Drive\PhD\Secondary_Protein_Structures"

Structures = ["DNA","Glycogen","Lipid","Protein","RNA"]

Data = {Name: pd.read_csv(os.path.join(secondary_protein_file, "{}.csv".format(Name)), names = ["Wavenumber", "Absorbance"]).set_index("Wavenumber") for Name in Structures}

# %%
plt.clf()
fig = plt.figure()
fig.patch.set_facecolor([1,1,1])

for name, df in Data.items():
    
    plt.plot(df, label = name)
    
plt.legend()
plt.show()

# %% [markdown]
# Importing FTIR cubes

# %%
import os

file_place = r"C:\Users\Conor\Desktop\Breast Cancer Data\br20832_cores\br20832_cores"
file_list = os.listdir(file_place)

image_list_directory = r"C:\Users\Conor\Desktop\Breast Cancer Data\overlay\overlay"
image_list = os.listdir(image_list_directory)

images = {file_name[:-4] : loadmat(os.path.join(file_place, file_name)) for file_name in file_list[:3]}

# %%
from scipy.io import loadmat

mat = loadmat(file_place + "\\" + os.listdir(file_place)[9])

mat["image"].shape

plt.clf()
#plt.imshow(mat["image"].mean(axis = 2), cmap = "viridis")
plt.imshow(mat["image"][:,:,80], cmap = "viridis")
plt.show()

# %%
from scipy import interpolate

X = mat["wn"]

wavenumbers = mat["wn"].T[0]

Secondary_Structures = {Name: interpolate.interp1d(spectrum.index, spectrum.values.flatten(), fill_value = "extrapolate") for Name, spectrum in Data.items()}

# %%
from sklearn.preprocessing import MinMaxScaler, Normalizer, RobustScaler
# Out:
# C:\Users\Conor\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# C:\Users\Conor\Anaconda3\lib\site-packages\scipy\_lib\_numpy_compat.py:10: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated since 1.15.0, import from numpy.testing instead.
#   from numpy.testing.nosetester import import_nose
# C:\Users\Conor\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# C:\Users\Conor\Anaconda3\lib\site-packages\scipy\stats\morestats.py:12: DeprecationWarning: Importing from numpy.testing.decorators is deprecated since numpy 1.15.0, import from numpy.testing instead.
#   from numpy.testing.decorators import setastest

# %%
Normed_Data = {Name: pd.DataFrame(RobustScaler().fit_transform(data(wavenumbers).reshape(1,-1))
             ,columns = wavenumbers) for Name, data in Secondary_Structures.items()}

Normed_Secondary = pd.concat(Normed_Data, axis = 0).reset_index().drop("level_1", axis = 1).set_index("level_0")

# %%
plt.clf()
fig = plt.figure()
fig.patch.set_facecolor([1,1,1])

Normed_Secondary.T.plot()

plt.show()

# %%
Normed_Secondary.to_pickle(os.path.join(os.getcwd(), "Secondary_Proteins"))

# %%
New = np.matmul(image.values, Normed_Secondary.values.T).reshape(313,313,5)

plt.clf()
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (20,5))
fig.patch.set_facecolor([1,1,1])

maximum = np.max([np.max(New[:,:,i]) for i in range(New.shape[2])])

for ax, i, name in zip(axes,range(5) , ["DNA","Glycogen","Lipid","Protein","RNA"]):
    
    print(i, name)
    
    ax.imshow(New[:,:,i], vmin = 0, vmax = 0.3, interpolation = "none")
    ax.set_title(name)
    ax.set_xticks([])
    ax.set_yticks([])
    
#fig.colorbar(ax.imshow(New[:,:,0]))
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5128315c8fb2> in <module>()
# ----> 1 New = np.matmul(image.values, Normed_Secondary.values.T).reshape(313,313,5)
#       2
#       3 plt.clf()
#       4 fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (20,5))
#       5 fig.patch.set_facecolor([1,1,1])
#
# NameError: name 'image' is not defined

# %% [markdown]
# Interpolate the secondary protein structures and re-range to be the same as the columns of the data
