# %%
# %load_ext autoreload

# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import SNOM_Import

import os

# %%
file_dir = "/home/conor/Desktop/CRUK Grant"

os.listdir(file_dir)[:5]
# Out:
# ['2147-0-HEADR.txt.txt',
#  '._2154-0-HEADR.txt.txt',
#  '2182-0-HEADR.txt.txt',
#  '2211-0-BSNOM.AFM',
#  '2163-0-BTOPO.AFM']

# %%
test_ = SNOM_Import.SNOM_File(os.path.join(file_dir, "2147-0"))

# %%
test_ = SNOM_Import.SNOM_File(os.path.join(file_dir, "2147-0"))

# %%
test_.HEADR
# Out:
# 'Number of Files              4 \n\nStart time=   14/03/2019 12:18:18\nEnd time=     14/03/2019 12:42:54\n\nPre Scan=     Oesophageal Tissue Sample for Testing\n----------------------\nFibre = 608-570 6 um cleaved\n\nSNOM Mode = Transmission\n\nScan Rate = 30.96 Hz\n----------------------\nAFM Gain = 5\nAmplitude = 0.057 V\nFrequency = 5.526 kHz\n\nVres = 0.020 V\nVref = 0.018 V\n-----------------------\nLaser Parameters\nWavenumber = 1242 cm-1\nPulse rate = 80 kHz\nPulse Width 500 ns\n---------------------\nLock-in Settings\nTime constant = 1 ms\nSensitivity = 150 mV\n----------------------\n\nPost Scan=    \n\nSample Tissue=              \nSample Patient=             \nSample Slice=               \nSample Position=            0\n\nSNOM mode=                  0\n\nWavelength=                 0 µ \nFEL_Power=                  0 mW \n\nScan Size=                   150 µ\nNum Points=                 150\nStep Size=                   1 µ\nX-Start=                    -200µ\nY-Start=                    -250µ\n'

# %%
datasets = {"HI_C6AU_PH7_A1":  [("2268-0",1626),("2267-0",1651),("2266-0",1689)],
            "HI_C6AU_PH7_A3":  [("2272-0",1626),("2273-0",1651),("2274-0",1689)],
            "HI_C18AU_PH7_A1": [("2257-0",1626),("2258-0",1651),("2259-0",1689)],
            "HI_C18AU_PH7_A2": [("2262-z000",1626),("2261-z000",1651),("2260-z000",1689)],
            "HI_C18AU_PH7_A3": [("2263-z000",1626),("2264-z000",1651),("2265-z000",1689)],
            "HI_C6AU_PH2_A2": [("2294-0",1626),("2295-0",1651),("2296-0",1689)],
            "HI_C18AU_PH2_A1": [("2278-0",1626),("2279-0",1651),("2280-0",1689)],
            "HI_C18AU_PH2_A2": [("2283-0",1626),("2282-0",1651),("2281-0",1689)],
            "HI_C18AU_PH2_A3": [("2284-0",1626),("2285-0",1651),("2286-0",1689)]
           }

# %%
labels = {1651: r"$\alpha$ Helix",
          1626: r"Parallel $\beta$",
          1689: r"Anti-parallel $\beta$"}

# %%
for data_set_name, dataset in datasets.items():

    plt.figure(figsize = (7.5,5))

    for im in dataset:

        img = SNOM_Import.SNOM_File(os.path.join(file_dir, im[0]))

        plt.hist((img.images["FSNOM"].image*img.sensitivity).flatten()
                 , label = "{} - {}$(cm^-1)$ ({})".format(im[0], im[1], labels[im[1]])
                 , histtype = "step"
                 , bins = 25
                 , density = True)
        
    plt.title(data_set_name)
    plt.xlabel("MCT signal (mV)")
    plt.ylabel("Frequency (arb.units)")
    plt.legend()
    plt.savefig(os.path.join("/home/conor/Desktop/Insulin_Histograms", data_set_name))

# %%
for im_name in HI_C6AU_PH7:
    
    img = SNOM_Import.SNOM_File(os.path.join(file_dir, im_name))

    plt.hist((img.images["FSNOM"].image).flatten(), label = im_name, histtype = "step")
    
plt.legend()

# %%
dir(SNOM_Import)
